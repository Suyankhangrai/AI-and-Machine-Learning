# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import random
from PIL import Image
from sklearn.metrics import classification_report

# %%
# !unzip 'FruitinAmazon.zip'
# Out:
# Archive:  FruitinAmazon.zip
#   inflating: FruitinAmazon/test/cupuacu/download (5).jpeg
#   inflating: FruitinAmazon/test/acai/images (2).jpeg
#   inflating: FruitinAmazon/test/cupuacu/download (3).jpeg
#   inflating: FruitinAmazon/test/acai/images (16).jpeg
#   inflating: FruitinAmazon/test/pupunha/download (2).jpeg
#   inflating: FruitinAmazon/train/pupunha/images (1).jpeg
#   inflating: FruitinAmazon/test/cupuacu/download (2).jpeg
#   inflating: FruitinAmazon/test/pupunha/download (1).jpeg
#   inflating: FruitinAmazon/train/acai/images (3).jpeg
#   inflating: FruitinAmazon/train/acai/images (4).jpeg
#   inflating: FruitinAmazon/test/graviola/download (1).jpeg
#   inflating: FruitinAmazon/test/pupunha/download (11).jpeg
#   inflating: FruitinAmazon/test/pupunha/download (4).jpeg
#   inflating: FruitinAmazon/train/acai/images (11).jpeg
#   inflating: FruitinAmazon/test/tucuma/download (1).jpeg
#   inflating: FruitinAmazon/test/acai/images.jpeg
#   inflating: FruitinAmazon/train/acai/images (10).jpeg
#   inflating: FruitinAmazon/test/cupuacu/images (3).jpeg
#   inflating: FruitinAmazon/train/acai/images (13).jpeg
#   inflating: FruitinAmazon/test/tucuma/download (5).jpeg
#   inflating: FruitinAmazon/test/graviola/images (4).jpeg
#   inflating: FruitinAmazon/train/acai/images (7).jpeg
#   inflating: FruitinAmazon/train/pupunha/images (6).jpeg
#   inflating: FruitinAmazon/train/acai/images (1).jpeg
#   inflating: FruitinAmazon/train/pupunha/images.jpeg
#   inflating: FruitinAmazon/train/acai/images (15).jpeg
#   inflating: FruitinAmazon/train/pupunha/images (4).jpeg
#   inflating: FruitinAmazon/test/cupuacu/download (4).jpeg
#   inflating: FruitinAmazon/train/pupunha/images (5).jpeg
#   inflating: FruitinAmazon/test/acai/download (9).jpeg
#   inflating: FruitinAmazon/train/acai/images (5).jpeg
#   inflating: FruitinAmazon/train/pupunha/images (8).jpeg
#   inflating: FruitinAmazon/train/acai/images (8).jpeg
#   inflating: FruitinAmazon/test/graviola/download (3).jpeg
#   inflating: FruitinAmazon/train/pupunha/images (3).jpeg
#   inflating: FruitinAmazon/train/acai/images (9).jpeg
#   inflating: FruitinAmazon/test/graviola/download (2).jpeg
#   inflating: FruitinAmazon/train/acai/images (14).jpeg
#   inflating: FruitinAmazon/test/guarana/download (2).jpeg
#   inflating: FruitinAmazon/train/pupunha/download.jpeg
#   inflating: FruitinAmazon/train/pupunha/images (10).jpeg
#   inflating: FruitinAmazon/train/acai/images (18).jpeg
#   inflating: FruitinAmazon/train/guarana/download (7).jpeg
#   inflating: FruitinAmazon/test/tucuma/download (8).jpeg
#   inflating: FruitinAmazon/train/pupunha/images (9).jpeg
#   inflating: FruitinAmazon/train/pupunha/images (7).jpeg
#   inflating: FruitinAmazon/train/guarana/images (8).jpeg
#   inflating: FruitinAmazon/train/pupunha/images (13).jpeg
#   inflating: FruitinAmazon/test/tucuma/download (4).jpeg
#   inflating: FruitinAmazon/train/guarana/download (8).jpeg
#   inflating: FruitinAmazon/test/guarana/download (4).jpeg
#   inflating: FruitinAmazon/test/pupunha/download (3).jpeg
#   inflating: FruitinAmazon/test/guarana/download (3).jpeg
#   inflating: FruitinAmazon/train/graviola/images (6).jpeg
#   inflating: FruitinAmazon/train/guarana/images (3).jpeg
#   inflating: FruitinAmazon/train/graviola/download (7).jpeg
#   inflating: FruitinAmazon/train/guarana/images.jpeg
#   inflating: FruitinAmazon/train/graviola/images (7).jpeg
#   inflating: FruitinAmazon/test/tucuma/download (2).jpeg
#   inflating: FruitinAmazon/train/guarana/images (1).jpeg
#   inflating: FruitinAmazon/train/guarana/download (6).jpeg
#   inflating: FruitinAmazon/train/pupunha/images (2).jpeg
#   inflating: FruitinAmazon/test/guarana/download (5).jpeg
#   inflating: FruitinAmazon/train/graviola/download (6).jpeg
#   inflating: FruitinAmazon/train/graviola/images (3).jpeg
#   inflating: FruitinAmazon/train/graviola/images (10).jpeg
#   inflating: FruitinAmazon/train/pupunha/images (12).jpeg
#   inflating: FruitinAmazon/train/graviola/images (8).jpeg
#   inflating: FruitinAmazon/train/guarana/download (10).jpeg
#   inflating: FruitinAmazon/train/tucuma/images (2).jpeg
#   inflating: FruitinAmazon/train/tucuma/images (1).jpeg
#   inflating: FruitinAmazon/train/guarana/images (6).jpeg
#   inflating: FruitinAmazon/train/guarana/images (5).jpeg
#   inflating: FruitinAmazon/train/guarana/download (1).jpeg
#   inflating: FruitinAmazon/train/guarana/images (2).jpeg
#   inflating: FruitinAmazon/train/tucuma/download (9).jpeg
#   inflating: FruitinAmazon/train/graviola/download (8).jpeg
#   inflating: FruitinAmazon/train/pupunha/images (11).jpeg
#   inflating: FruitinAmazon/train/acai/images (6).jpeg
#   inflating: FruitinAmazon/test/guarana/images (4).jpeg
#   inflating: FruitinAmazon/train/graviola/download (5).jpeg
#   inflating: FruitinAmazon/train/tucuma/images.jpeg
#   inflating: FruitinAmazon/train/tucuma/images (9).jpeg
#   inflating: FruitinAmazon/train/graviola/download.jpeg
#   inflating: FruitinAmazon/train/graviola/images (5).jpeg
#   inflating: FruitinAmazon/train/graviola/images (2).jpeg
#   inflating: FruitinAmazon/train/guarana/download (9).jpeg
#   inflating: FruitinAmazon/train/acai/images (12).jpeg
#   inflating: FruitinAmazon/train/tucuma/images (3).jpeg
#   inflating: FruitinAmazon/train/tucuma/images (7).jpeg
#   inflating: FruitinAmazon/train/graviola/images.jpeg
#   inflating: FruitinAmazon/train/tucuma/images (5).jpeg
#   inflating: FruitinAmazon/train/tucuma/download (3).jpeg
#   inflating: FruitinAmazon/train/cupuacu/images (4).jpeg
#   inflating: FruitinAmazon/train/cupuacu/images (7).jpeg
#   inflating: FruitinAmazon/train/cupuacu/download.jpeg
#   inflating: FruitinAmazon/test/acai/images (17).jpeg
#   inflating: FruitinAmazon/train/graviola/images (1).jpeg
#   inflating: FruitinAmazon/train/cupuacu/images (13).jpeg
#   inflating: FruitinAmazon/train/cupuacu/images (12).jpeg
#   inflating: FruitinAmazon/train/tucuma/download (6).jpeg
#   inflating: FruitinAmazon/train/cupuacu/images (5).jpeg
#   inflating: FruitinAmazon/train/guarana/images (7).jpeg
#   inflating: FruitinAmazon/train/tucuma/images (6).jpeg
#   inflating: FruitinAmazon/train/cupuacu/images (6).jpeg
#   inflating: FruitinAmazon/train/tucuma/images (8).jpeg
#   inflating: FruitinAmazon/train/cupuacu/download (1).jpeg
#   inflating: FruitinAmazon/test/graviola/download (4).jpeg
#   inflating: FruitinAmazon/train/tucuma/images (4).jpeg
#   inflating: FruitinAmazon/train/cupuacu/images (8).jpeg
#   inflating: FruitinAmazon/train/cupuacu/images (1).jpeg
#   inflating: FruitinAmazon/train/cupuacu/images (10).jpeg
#   inflating: FruitinAmazon/train/tucuma/download (7).jpeg
#   inflating: FruitinAmazon/train/guarana/download.jpeg
#   inflating: FruitinAmazon/train/cupuacu/images (2).jpeg
#   inflating: FruitinAmazon/train/graviola/images (9).jpeg
#   inflating: FruitinAmazon/train/cupuacu/images (11).jpeg
#   inflating: FruitinAmazon/train/cupuacu/images (9).jpeg
#   inflating: FruitinAmazon/train/tucuma/download.jpeg
#   inflating: FruitinAmazon/train/cupuacu/images.jpeg

# %% [markdown]
# DATASET PATH

# %%
train_dir = "/content/FruitinAmazon/test"
test_dir = "/content/FruitinAmazon/train"

# %% [markdown]
# VERIFY DATASET

# %%
class_names = sorted(os.listdir(train_dir))

if not class_names:
    print("No class directories found!")
else:
    print(f"Found {len(class_names)} classes:", class_names)
# Out:
# Found 6 classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %% [markdown]
# TASK 1: CHECK CORRUPTED IMAGES

# %%
from PIL import UnidentifiedImageError

corrupted_images = []

for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)

    for img_name in os.listdir(class_path):
        img_path = os.path.join(class_path, img_name)

        try:
            with Image.open(img_path) as img:
                img.verify()
        except (IOError, UnidentifiedImageError):
            corrupted_images.append(img_path)

if corrupted_images:
    print("Corrupted Images Found:")
    for img in corrupted_images:
        print(img)
else:
    print("No corrupted images found.")
# Out:
# No corrupted images found.

# %% [markdown]
# TASK 1: CLASS DISTRIBUTION

# %%
class_counts = {}

for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    images = [img for img in os.listdir(class_path) if img.endswith(('.jpg','.png','.jpeg'))]
    class_counts[class_name] = len(images)

print("\nClass Distribution:")
print("="*40)
for k, v in class_counts.items():
    print(f"{k:<20} {v}")
# Out:
# Class Distribution:
# ========================================
# acai                 5
# cupuacu              5
# graviola             5
# guarana              5
# pupunha              5
# tucuma               5

# %% [markdown]
# TASK 1: RANDOM IMAGE VISUALIZATION

# %%
selected_images = []
selected_labels = []

for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    images = os.listdir(class_path)

    img_path = os.path.join(class_path, random.choice(images))

    selected_images.append(img_path)
    selected_labels.append(class_name)

cols = (len(selected_images)+1)//2
rows = 2

fig, axes = plt.subplots(rows, cols, figsize=(12,6))

for i, ax in enumerate(axes.flat):
    if i < len(selected_images):
        img = plt.imread(selected_images[i])
        ax.imshow(img)
        ax.set_title(selected_labels[i])
        ax.axis("off")
    else:
        ax.axis("off")

plt.show()

# %% [markdown]
# TASK 2: LOAD DATASET

# %%
img_size = (128,128)
batch_size = 32

train_ds, val_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    validation_split=0.2,
    subset="both",
    seed=1337,
    image_size=img_size,
    batch_size=batch_size
)
# Out:
# Found 30 files belonging to 6 classes.
# Using 24 files for training.
# Using 6 files for validation.

# %% [markdown]
# VISUALIZE BATCH

# %%
plt.figure(figsize=(10,10))

for images, labels in train_ds.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(labels[i].numpy())
        plt.axis("off")

plt.show()

# %% [markdown]
# TASK 3: DATA AUGMENTATION

# %%
from tensorflow.keras import layers

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

# %% [markdown]
# TASK 3: MODEL WITH BN + DROPOUT

# %%
num_classes = len(class_names)

model = tf.keras.Sequential([

    data_augmentation,
    layers.Rescaling(1./255),

    layers.Conv2D(32, (3,3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),

    layers.Conv2D(64, (3,3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),

    layers.Conv2D(128, (3,3), padding='same'),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D(),
    layers.Dropout(0.25),

    layers.Flatten(),

    layers.Dense(256),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.5),

    layers.Dense(128),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.Dropout(0.5),

    layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# COMPILE

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# TRAIN

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50
)
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.1667 - loss: 2.7109 - val_accuracy: 0.0000e+00 - val_loss: 1.9415
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.2917 - loss: 2.0715 - val_accuracy: 0.0000e+00 - val_loss: 2.0178
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.3333 - loss: 1.6119 - val_accuracy: 0.0000e+00 - val_loss: 2.1340
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5833 - loss: 1.0742 - val_accuracy: 0.0000e+00 - val_loss: 2.1578
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5000 - loss: 1.2321 - val_accuracy: 0.0000e+00 - val_loss: 2.0925
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6667 - loss: 1.2303 - val_accuracy: 0.1667 - val_loss: 2.0197
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5833 - loss: 1.0066 - val_accuracy: 0.1667 - val_loss: 1.9829
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4167 - loss: 1.4147 - val_accuracy: 0.1667 - val_loss: 1.9428
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7500 - loss: 0.7858 - val_accuracy: 0.3333 - val_loss: 1.9095
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.6250 - loss: 1.0624 - val_accuracy: 0.5000 - val_loss: 1.8932
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 991ms/step - accuracy: 0.6667 - loss: 0.8592 - val_accuracy: 0.5000 - val_loss: 1.8409
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 962ms/step - accuracy: 0.6250 - loss: 0.8226 - val_accuracy: 0.5000 - val_loss: 1.8050
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7500 - loss: 0.7209 - val_accuracy: 0.5000 - val_loss: 1.7655
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.8333 - loss: 0.6468 - val_accuracy: 0.5000 - val_loss: 1.7333
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8750 - loss: 0.5072 - val_accuracy: 0.5000 - val_loss: 1.7012
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7917 - loss: 0.6479 - val_accuracy: 0.5000 - val_loss: 1.6673
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8750 - loss: 0.4909 - val_accuracy: 0.5000 - val_loss: 1.6531
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8750 - loss: 0.4575 - val_accuracy: 0.1667 - val_loss: 1.6625
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7083 - loss: 0.6676 - val_accuracy: 0.1667 - val_loss: 1.6832
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step - accuracy: 0.7917 - loss: 0.6136 - val_accuracy: 0.1667 - val_loss: 1.7034
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.7917 - loss: 0.5266 - val_accuracy: 0.1667 - val_loss: 1.7239
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step - accuracy: 0.8333 - loss: 0.4310 - val_accuracy: 0.1667 - val_loss: 1.7512
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9583 - loss: 0.2948 - val_accuracy: 0.1667 - val_loss: 1.7788
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.8750 - loss: 0.4476 - val_accuracy: 0.1667 - val_loss: 1.8070
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9583 - loss: 0.2596 - val_accuracy: 0.1667 - val_loss: 1.8410
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.9583 - loss: 0.3333 - val_accuracy: 0.3333 - val_loss: 1.8761
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.2590 - val_accuracy: 0.3333 - val_loss: 1.9106
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.1823 - val_accuracy: 0.3333 - val_loss: 1.9510
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9583 - loss: 0.2710 - val_accuracy: 0.3333 - val_loss: 1.9902
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.2119 - val_accuracy: 0.3333 - val_loss: 2.0264
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.8750 - loss: 0.3471 - val_accuracy: 0.3333 - val_loss: 2.0661
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.9583 - loss: 0.2396 - val_accuracy: 0.3333 - val_loss: 2.1072
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.9167 - loss: 0.3443 - val_accuracy: 0.3333 - val_loss: 2.1465
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9583 - loss: 0.2245 - val_accuracy: 0.3333 - val_loss: 2.1924
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9583 - loss: 0.2178 - val_accuracy: 0.3333 - val_loss: 2.2381
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step - accuracy: 1.0000 - loss: 0.2095 - val_accuracy: 0.3333 - val_loss: 2.2819
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9167 - loss: 0.2279 - val_accuracy: 0.3333 - val_loss: 2.3175
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.1870 - val_accuracy: 0.3333 - val_loss: 2.3497
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.9583 - loss: 0.2084 - val_accuracy: 0.3333 - val_loss: 2.3782
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 939ms/step - accuracy: 1.0000 - loss: 0.1397 - val_accuracy: 0.3333 - val_loss: 2.4043
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.1732 - val_accuracy: 0.3333 - val_loss: 2.4339
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.1628 - val_accuracy: 0.3333 - val_loss: 2.4652
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step - accuracy: 1.0000 - loss: 0.0873 - val_accuracy: 0.3333 - val_loss: 2.4952
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.1677 - val_accuracy: 0.3333 - val_loss: 2.5236
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.1054 - val_accuracy: 0.3333 - val_loss: 2.5497
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.0793 - val_accuracy: 0.3333 - val_loss: 2.5770
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.1008 - val_accuracy: 0.3333 - val_loss: 2.6135
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.9583 - loss: 0.1236 - val_accuracy: 0.3333 - val_loss: 2.6480
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 1.0000 - loss: 0.0687 - val_accuracy: 0.3333 - val_loss: 2.6774
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 1.0000 - loss: 0.1152 - val_accuracy: 0.3333 - val_loss: 2.7078

# %% [markdown]
# EVALUATE

# %%
loss, acc = model.evaluate(val_ds)
print("Validation Accuracy:", acc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3333 - loss: 2.7078
# Validation Accuracy: 0.3333333432674408

# %% [markdown]
# CLASSIFICATION REPORT

# %%
y_true = []
y_pred = []

for images, labels in val_ds:
    preds = model.predict(images)
    preds = np.argmax(preds, axis=1)

    y_true.extend(labels.numpy())
    y_pred.extend(preds)

print(classification_report(y_true, y_pred))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
#               precision    recall  f1-score   support
#
#            1       0.33      1.00      0.50         2
#            4       0.00      0.00      0.00         1
#            5       0.00      0.00      0.00         3
#
#     accuracy                           0.33         6
#    macro avg       0.11      0.33      0.17         6
# weighted avg       0.11      0.33      0.17         6
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# TASK 2: TRANSFER LEARNING

# %% [markdown]
# LOAD VGG16

# %%
from tensorflow.keras.applications import VGG16

base_model = VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(128,128,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# FREEZE LAYERS

# %%
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# ADD CUSTOM LAYERS

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
outputs = Dense(num_classes, activation='softmax')(x)

model_tl = Model(inputs=base_model.input, outputs=outputs)

# %% [markdown]
# COMPILE

# %%
model_tl.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
#  TRAIN

# %%
history_tl = model_tl.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20
)
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 0.2917 - loss: 11.9468 - val_accuracy: 0.3333 - val_loss: 6.4252
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.4583 - loss: 4.0540 - val_accuracy: 0.1667 - val_loss: 9.2801
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.6667 - loss: 2.2143 - val_accuracy: 0.1667 - val_loss: 11.6849
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 0.7500 - loss: 1.4555 - val_accuracy: 0.1667 - val_loss: 12.1462
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.8333 - loss: 0.8372 - val_accuracy: 0.3333 - val_loss: 11.9642
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.9583 - loss: 0.2981 - val_accuracy: 0.3333 - val_loss: 11.8731
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 1.0000 - loss: 0.0350 - val_accuracy: 0.3333 - val_loss: 11.8054
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.3333 - val_loss: 12.1815
# Epoch 9/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 1.0000 - loss: 7.4945e-04 - val_accuracy: 0.3333 - val_loss: 12.6461
# Epoch 10/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 1.0000 - loss: 4.4923e-04 - val_accuracy: 0.3333 - val_loss: 13.1144
# Epoch 11/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 1.0000 - loss: 4.1414e-04 - val_accuracy: 0.3333 - val_loss: 13.5958
# Epoch 12/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 1.0000 - loss: 5.7039e-04 - val_accuracy: 0.3333 - val_loss: 14.0740
# Epoch 13/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 1.0000 - loss: 9.0818e-04 - val_accuracy: 0.3333 - val_loss: 14.5067
# Epoch 14/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.3333 - val_loss: 14.8921
# Epoch 15/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.3333 - val_loss: 15.2201
# Epoch 16/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.3333 - val_loss: 15.5045
# Epoch 17/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.3333 - val_loss: 15.7532
# Epoch 18/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 1.0000 - loss: 7.5382e-04 - val_accuracy: 0.3333 - val_loss: 15.9708
# Epoch 19/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 1.0000 - loss: 4.6154e-04 - val_accuracy: 0.3333 - val_loss: 16.1681
# Epoch 20/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 1.0000 - loss: 2.8400e-04 - val_accuracy: 0.3333 - val_loss: 16.3464
